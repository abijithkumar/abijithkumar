# %% [markdown]
# <a href="https://colab.research.google.com/github/abijithkumar/abijithkumar/blob/main/dev_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("passengers.csv")

# %%
th=df.head(1000)
th
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1    05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 2    03/01/2007  2007      3       10721     BOS       13      12651    KEF
# 3    12/01/2004  2004     12       11259     DAL       74      16271    YYZ
# 4    05/01/2009  2009      5       13303     MIA       33      11075    CMW
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  12/01/2003  2003     12       12478     JFK       22      14293    PUJ
# 996  02/01/2008  2008      2       13930     ORD       41      15455    UIO
# 997  12/01/2007  2007     12       15842     WRI       21      16050    YFB
# 998  02/01/2007  2007      2       13061     LRD       74      16477    QRO
# 999  06/01/2002  2002      6       14761     SFB       33      12966    LGW
#
# ...

# %%
th.describe()
# Out:
#               Year        Month    usg_apt_id      usg_wac     fg_apt_id  \
# count  1000.000000  1000.000000   1000.000000  1000.000000   1000.000000
# mean   2005.609000     6.401000  13034.253000    41.061000  13664.921000
# std       2.685765     3.421974   4177.222797    24.564134   1876.158568
# min    2001.000000     1.000000  10135.000000     1.000000  10148.000000
# 25%    2003.000000     3.000000  11618.000000    22.000000  12040.750000
# 50%    2006.000000     6.000000  13082.000000    33.000000  13611.500000
# 75%    2008.000000     9.000000  13930.000000    63.000000  15306.000000
# max    2010.000000    12.000000  99999.000000    93.000000  16477.000000
#
#             fg_wac     airlineid  carriergroup  Scheduled      Charter  \
# count  1000.000000   1000.000000   1000.000000     1000.0  1000.000000
# mean    463.570000  20238.434000      0.790000        0.0     7.447000
# std     295.228591    303.906764      0.407512        0.0    13.696159
# ...

# %%
th.shape
# Out:
# (1000, 16)

# %%
th.columns
# Out:
# Index(['data_dte', 'Year', 'Month', 'usg_apt_id', 'usg_apt', 'usg_wac',
#        'fg_apt_id', 'fg_apt', 'fg_wac', 'airlineid', 'carrier', 'carriergroup',
#        'type', 'Scheduled', 'Charter', 'Total'],
#       dtype='object')

# %%
th.nunique()
# Out:
# data_dte        120
# Year             10
# Month            12
# usg_apt_id      169
# usg_apt         169
# usg_wac          45
# fg_apt_id       232
# fg_apt          231
# fg_wac           88
# airlineid       129
# carrier         134
# carriergroup      2
# type              1
# Scheduled         1
# Charter          58
# Total            58
# dtype: int64

# %%
th.tail()
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 995  12/01/2003  2003     12       12478     JFK       22      14293    PUJ
# 996  02/01/2008  2008      2       13930     ORD       41      15455    UIO
# 997  12/01/2007  2007     12       15842     WRI       21      16050    YFB
# 998  02/01/2007  2007      2       13061     LRD       74      16477    QRO
# 999  06/01/2002  2002      6       14761     SFB       33      12966    LGW
#
#      fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 995     224      20147      T9           1.0  Departures        0.0      1.0
# 996     337      20007      5Y           1.0  Departures        0.0      1.0
# 997     934      20169      L2           1.0  Departures        0.0      5.0
# 998     148      20201     AMQ           1.0  Departures        0.0      1.0
# 999     493      19858      ZB           0.0  Departures        0.0      1.0
#
#      Total
# 995    1.0
# 996    1.0
# ...

# %%
th.isnull().sum()
# Out:
# data_dte         0
# Year             0
# Month            0
# usg_apt_id       0
# usg_apt          0
# usg_wac          0
# fg_apt_id        0
# fg_apt           0
# fg_wac           0
# airlineid        0
# carrier         10
# carriergroup     0
# type             0
# Scheduled        0
# Charter          0
# Total            0
# dtype: int64

# %%
h = th.head(100)
h
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1   05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 2   03/01/2007  2007      3       10721     BOS       13      12651    KEF
# 3   12/01/2004  2004     12       11259     DAL       74      16271    YYZ
# 4   05/01/2009  2009      5       13303     MIA       33      11075    CMW
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  09/01/2005  2005      9       11540     ELP       74      16078    YHM
# 96  12/01/2001  2001     12       12892     LAX       91      13252    MEX
# 97  07/01/2002  2002      7       13891     ONT       91      13594    MZT
# 98  08/01/2009  2009      8       13667     NGU       38      13618    NBW
# 99  06/01/2009  2009      6       15045     SUU       91      13856    OKO
#
# ...

# %%
 a  = th.drop(['type'],axis=1)
a
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1    05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 2    03/01/2007  2007      3       10721     BOS       13      12651    KEF
# 3    12/01/2004  2004     12       11259     DAL       74      16271    YYZ
# 4    05/01/2009  2009      5       13303     MIA       33      11075    CMW
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  12/01/2003  2003     12       12478     JFK       22      14293    PUJ
# 996  02/01/2008  2008      2       13930     ORD       41      15455    UIO
# 997  12/01/2007  2007     12       15842     WRI       21      16050    YFB
# 998  02/01/2007  2007      2       13061     LRD       74      16477    QRO
# 999  06/01/2002  2002      6       14761     SFB       33      12966    LGW
#
# ...

# %%
x=th.usg_wac
y=th.fg_wac
a=th.usg_wac
b=th.fg_wac
plt.scatter(x,y)
plt.xlabel('usg_wac')
plt.ylabel('fg_wac')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(h.usg_apt_id,h.usg_wac)
plt.xlabel('usg_apt_id')
plt.ylabel('usg_wac')
# Out:
# Text(0, 0.5, 'usg_wac')

# %%
plt.bar(h.usg_apt_id,h.usg_wac, color = "red")
plt.xlabel('usg_apt_id')
plt.ylabel('usg_wac')
# Out:
# Text(0, 0.5, 'usg_wac')

# %%
plt.barh(h.usg_apt_id,h.usg_wac,color = "pink")
plt.xlabel('usg_apt_id')
plt.ylabel('usg_wac')
# Out:
# Text(0, 0.5, 'usg_wac')

# %%
plt.hist(h.usg_apt_id,color = "red")
plt.xlabel('usg_apt_id')
# Out:
# Text(0.5, 0, 'usg_apt_id')

# %%
plt.pie(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# Text(0.5, 0, 'usg_wac')

# %%
plt.stem(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'usg_wac')

# %%
plt.polar(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# Text(0.5, 0, 'usg_wac')
